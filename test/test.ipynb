# %%
# %load_ext autoreload
# %autoreload 2

# %%
import imageio as iio
from PIL import Image
import numpy as np

import sys, os
sys.path.append(os.path.join(os.path.dirname(sys.path[0]),'src'))
from filters import guided_filter

# %%
im = iio.imread('../data/petrovic/fused012_1.tif')
Image.fromarray(im)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x27507EC8250>

# %%
# %%time
gf = guided_filter(im/255, im/255, 5, 0.1)
Image.fromarray((gf*255).astype(np.uint8))
# Out:
# Wall time: 233 ms
# <PIL.Image.Image image mode=L size=512x512 at 0x27507E73730>

# %%
im2 = iio.imread('../data/lytro/lytro-01-A.jpg')
Image.fromarray(im2)
# Out:
# <PIL.Image.Image image mode=RGB size=520x520 at 0x27509B1CFD0>

# %%
gf = guided_filter(im2/255, im2[:,:,0]/255, 5,0.05)
Image.fromarray((gf*255).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=520x520 at 0x27509B2F670>

# %%
from filters import guided_filter_rgb

# %%
gf1 = guided_filter_rgb(im2/255, im2/255, 5,0.05)
Image.fromarray((gf1*255).astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=520x520 at 0x27509B2F2E0>
